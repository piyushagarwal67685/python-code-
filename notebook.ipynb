# %%
# #arithmetic opr
# a = 10
# b = 20
# print(a+b)

# c = 20
# d = 10
# print(c-d)

# e = 10
# f = 5
# print(e*f)

# g = 10
# h = 2
# print(g/h)

# i = 9
# j = 2
# print(i%j)

# k = 5
# l = 2
# print(k ** l)


# print(10*2+10/5+2)

# relational opr
# a = 20
# b = 20
# print(a > b) # false
# print( a < b) # true

# print(a == b) # true
# a = b
# print(a == b)

# # swapping
# a = 10
# b = 20
# # before swapping
# print(a)
# print(b)

# a,b = b,a
# # after swapping
# print(a)
# print(b)

# a = 10
# b = 20
# print( a >= 20)
# print( a <= 20)
# print( a == b)

# logical opr
# a = [10]
# b = "0"
# if a and b :
#   print("hello")
# else:
#   print("no")

# a = []
# b = 10
# print(not a or b)


# # Bitwise opr
# a = 5
# b = 3
# print(a & b)
# print(a | b)

# a = 10
# b = 7

# a = ["stu1","stu2","stu3","stu4"]
# b = "stu3"

# print(b in a)

# c = {"name":"raj","age":20}
# d = "age"

# print(d in c)

# condition statement

# a = 10
# if a == 10:
#   print("a == 10")
# else:
#   print("a not equal to 10")


# b = 20
# if b < 10 :
#   print("b less than 10")
# elif b == 10:
#   print("b equal to 10")
# else:
#   print("b is greater then 10")


# marks = 86
# if marks >= 95 and marks < 101:
#   print("grade a")
# elif marks >= 85:
#   print("grade b")
# elif marks >= 60:
#   print("grade c")
# else:
#   print("fail")


# dict = {"class":[10,20,30],"student":["ram","shyam","ganshyam"]}
# c = 10
# s = "ram"
# if c in dict["class"]:
#   print("class present",c)
# else:
#   print("class not present",c)

# a = input("Enter your name: ")
# print(a)

# b = int(input("Enter your age"))

# print(type(b))
# print("b = ",b)

# age = int(input("Enter your age: "))

# print("my age is " , age)


# name = "hello"
# print((name + "_" + "\n") * 10)


# print("Aello" <"aello") # A = 65 , a = 97


# print( not ["abf"] <= [])



# age = int(input("Enter your age: "))

# if age >= 18:
#   if age == 18:
#     print(f"you are equal to : {age}")
#   else:
#     print(f"you are: {age}")
# else:
#   print(f"less then: {age}")


# a = input("enter movie 1: ")
# b = input("enter movie 2: ")
# c = input("enter movie 3: ")
# dict = { "movies": [a,b,c]}
# # print(dict["movies"])

# search = input("search movie: ")
# # print(search)

# if search in dict['movies']:
#   print("present")
# else:
#   print("not available")


# a = input("model of mahindra car name: ")
# b = input("model of honda car name")
# dict = {"cars":{"mahindra":a,"honda":b}}
# brand = input("Enter car brand: ")
# car = input("Enter car name: ")

# if brand in dict["cars"]:
#   if car == dict["cars"][brand]:
#     print(f"{car} of brand {brand} is available")
#   else:
#     print(f"{car} of brand {brand} not available")


# sec_no = 3
# guess = int(input("enter guesss no :"))
# while guess != sec_no:
#   guess = int(input("enter guess no :"))

# 2 print

# a = input("enter your name: ")
# dict = {"name":a}
# l = ["ram","shyam","ganshyam"]
# i = 0
# while i < len(l):
#   if dict['name'] == l[i]:
#     print("your name is present in the list")
#   i += 1



# for loop
# dict = {"full name":{"nick name":["hello","raj"]}}
# # print(dict["full name"]["nick name"])

# # method 1
# for i in range(len(dict["full name"]["nick name"])):
#   print(dict["full name"]["nick name"][i])

# # method 2
# for i in dict["full name"]["nick name"]:
#   print(i)


# dict = {"clothes":[{"name":"shirt"},{"name":"jeans"},{"name":"t-shirt"}]}
# for i in dict["clothes"]:
#   print(i["name"])


# dict = {"bags":[{"sky bags":["bag1","bag2","bag3","bag4"]}]}



# def input_fun():
#   return 10

# a = input_fun()
# print(a)


# dict = {"phones":{"iphone":[12,13,14,15,16,17,18]}}
# print(dict["phones"]["iphone"])
# for i in dict["phones"]["iphone"]:
#   print(i)

# print()
# c = len(dict["phones"]["iphone"])
# for i in range(len(dict["phones"]["iphone"])):
#   print(dict["phones"]["iphone"][i])

# print(reverse(dict))
# Out:
# 18
# 17
# 16
# 15
# 14
# 13
# 12

# %% [markdown]
# **Data Types**

# %%
#Intergers
print(8)
#1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
#Decimal/Float
print(8.55)
#1*10^308
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/ String
print('Hello World')
# Out:
# Hello World

# %%
#Complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List
print([1,2,3,4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#Tuple
print((1,2,3,4,5,6))
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Sets
print({1,2,3,4,5,6})
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Dictionary
print({'name':'nitin','gender':'male'})
# Out:
# {'name': 'nitin', 'gender': 'male'}

# %%
# Type function
type(3)
# Out:
# int

# %% [markdown]
# **Variable**
#
# *   Static vs Dynamic typing
# *   Static vs Dynamic binding
# *   stylish declaration techniques

# %%
name = 'nitish'
print(name)

a = 5
b = 6
print(a+b)
# Out:
# nitish
# 11

# %%
#Dynamic typing
a = 5 # python support dynamic typing
# Static typing
# int a = 5 -> in other languages

# %%
#Dynamic binding
a = 5 # python support dynamic binding
print(a)
a = 'nitish'
print(a)

# Static binding
# int a = 5; -> in other languages
# int a = "nitish" -> its not possible
# Out:
# 5
# nitish

# %%
a = 5
b = 6
c = 7
print(a,b,c)
# Out:
# 5 6 7

# %%
a,b,c = 5,6,7
print(a,b,c)
# Out:
# 5 6 7

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# **Keyword and Identifiers**

# %%
# 32 reserver key words in python
#Identifiers can't start with a digit
name1 = 'nitish'
print(name)
# use can use special character -> _
first_name = 'hello'
print(first_name)
__ = 'world'
print(__)
# Identifiers can not be keyword
# Out:
# nitish
# hello
# world

# %% [markdown]
# **User Input**

# %%
input("Enter your name")
# Out:
# Enter your namehi
# 'hi'

# %%
#Take input from user and store them in variable
# add the 2 variables
# print the result
fnum = input("Enter first number:")
snum = input("Enter second number:")
print(type(fnum),type(snum))
#print the result
result = int(fnum) + int(snum)
print(result)
print(type(result))
print(type(fnum))
# Out:
# Enter first number:10
# Enter second number:20
# <class 'str'> <class 'str'>
# 30
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **Type Conversion**

# %%
# Implicit and Explicit
print(5+5.6) # example of implicit
print(type(5),type(5.6))

print(4+int('5')) # example of explicit
# Out:
# 10.6
# <class 'int'> <class 'float'>
# 9

# %% [markdown]
# **Operators**

# %%
#Arithmetic
#Relational
#Logical
#Bitwise
#Assignment
#Membership
