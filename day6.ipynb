# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushagarwal67685/python-code-/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# constructor

# %%
class address:
  city = "jaipur"
  state = "rajasthan"
  def __init__(self,city,state): #this -> self
    self.city = city
    self.state = state

a = address("jaipur","rajasthan")
print(a.state)
# Out:
# rajasthan

# %% [markdown]
# class method and self

# %%
class address:
  def __init__(self,city,state):
    self.city = city
    self.state = state

    def show(self):  #method
      print("the city is :",self.city)

      a = address("jaipur","rajasthan") # a -> object
      a.show()

# %% [markdown]
# inheritance

# %%
class address:
  def __init__(self,city,state):
    self.city = city
    self.state = state

    def location(self):
      return f"my location is {self.city}in{self.state}"

class user(address):
  def __init__(self,name,age,city,state):
    self.name = name
    self.age = age
    self.city = city
    self.state = state

  def username(self):
    print(f"my name is {self.name}")

    def userdetails(self):
      print(f"my name is {self.name} and my loaction is {self.city} in {self.state}")

    u = user("piyush",19,"kukas","rajasthan")
    print(u.city)
    u.userdetails()
    u.location
      # = address("kukas","rajasthan")

# %% [markdown]
# Encapsulation

# %%
class address:
  def __init__(self,city,state):
    self.city = city #attribute
    self.state = state

    def location(self):
      print(f"my location is {self.city}in{self.state}")

      def getcity(self):
        return self.city


      a = address("jaipur","rajasthan")
      a.location()
      print(a.city)
      print(a.state)

# %% [markdown]
# Poly morphism

# %%
class address:
  def __init__(self,city,state):
    self.city = city
    self.state = state
    def location(self):
      print(f"my location is {self.city}in{self.state}")

class hometown:
  def __init__(self,city,state):
    self.city = city
    self.state = state

    def location(self):
      print(f"my home town location is {self.city} in {self.state}")

a = address("jaipur","rajasthan")

b = hometown("sodala","gujarat")

# %% [markdown]
# class variable

# %%
class address:
  total = 10 #class variable
  def __init__(self,city,state):
    self.city = city
    self.state = state
    address.total +=1

  def location(self):
    print("location")

    a = address("jaipur","rajasthan")

    b = address("sodala","gujarat")

    a.total

# %% [markdown]
# overloading and overriding

# %%
#overloading -> not possible
def address(city,state): # parameter -> 2
 print(f"my address is {city} in {state} ")

def address(city,state,country): #parameter -> 3
 print(f"my address is {city} at {state} in {country}")

address("chapra","bihar")
address("jaipur","rajasthan","India")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2774/2953711405.py in <cell line: 0>()
#       6  print(f"my address is {city} at {state} in {country}")
#       7
# ----> 8 address("chapra","bihar")
#       9 address("jaipur","rajasthan","India")
#
# TypeError: address() missing 1 required positional argument: 'country'

# %%
#over riding
class address:
  def __init__(self,city,state):
    self.city = city
    self.state = state
    def location(self):
      print("address")

class user(address):
  def __init__(self,name,age,city, state):
    super().__init__(city, state)
    self.name = name
    self.age = age
    def location(self): #over riding
      print("user location")

u = User("arya mains",20,"kukas","rajashtan")
u.location()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2774/2787340242.py in <cell line: 0>()
#      16
#      17 u = user("arya mains",20,"kukas","rajashtan")
# ---> 18 U.location()
#
# NameError: name 'U' is not defined

# %% [markdown]
# tuples

# %%
#immutable -> not change
#t = (10,20,30)
#print(t[0])
#print(t[-1])

#example
marks = [98,90,80,95]
#list -> change
#marks[3] = 50
#print(type(marks))
#print(marks)
#tuple  -> not change
t = tuple(marks)
print(type(t))
print(t)

#tuple ->
m = list(t)
print(type(m))
print(m)
# Out:
# <class 'tuple'>
# (98, 90, 80, 95)
# <class 'list'>
# [98, 90, 80, 95]
